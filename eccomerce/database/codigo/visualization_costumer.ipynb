# %% [markdown]
# ##Instalando bibliotecas

# %%
 # !pip install 'fsspec>=0.3.3'
# Out:
# Requirement already satisfied: fsspec>=0.3.3 in /usr/local/lib/python3.7/dist-packages (2021.11.1)

# %% [markdown]
# ##Importando Bibliotecas e arquivos do drive

# %%
import dask.dataframe as dd
import plotly.express as px

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"
# Out:
#  bcc201.pdf
#  Classroom
# 'Colab Notebooks'
#  Estudos.pdf
#  ImersaoDev_Alura
# 'Iniciação Científica'
# 'karinemarins_historicoescolar (1).pdf'
# 'karinemarins_historicoescolar (2).pdf'
#  karinemarins_historicoescolar.pdf
#  Modelo_Plano_de_Ensino_BCC221-2021-1.pdf
# 'MTM112 T81T85T86 professor Isaque Viza de Souza.pdf'
#  Obra
# 'PlanoEnsRemoto Fundamentos GeaCV (1)-convertido.pdf'
# 'Relatorio TP1 - ED2.gdoc'
#  UFOP
# 'Voluta '
#  Wizard

# %% [markdown]
# ##Lendo os dados

# %%
df = dd.read_csv('/content/drive/MyDrive/Colab Notebooks/IC/eccomerce/database/olist_geolocated_transactions.csv')

# %%
df.columns

# %%
df = df.compute()

# %%
df.info()

# %%
df.head(10)

# %% [markdown]
# ##Visualizações para costumer

# %%
fig = px.scatter_mapbox(df, lat='costumer_lat', lon='costumer_lng',
                        color_discrete_sequence=["fuchsia"], zoom=3, height=1000)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ###Price

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='price', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Freight Value

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='freight_value', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Payment Sequential

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='payment_sequential', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Payment installments

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='payment_installments', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Payment Value

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='payment_value', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Review Score

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='review_score', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ##Analises para os produtos: altura, largura e etx

# %% [markdown]
# ###Description lenght

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='product_description_lenght', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Photos

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='product_photos_qty', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Weight

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='product_weight_g', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Lenght

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='product_length_cm', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Height

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='product_height_cm', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Width

# %%
fig = px.density_mapbox(df, lat='costumer_lat', lon='costumer_lng', z='product_width_cm', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ###Com as variaveis que foram codificadas

# %%
df_codificado = dd.read_csv('/content/drive/MyDrive/Colab Notebooks/IC/eccomerce/database/olist_geoleocated_encoder.csv')

# %%
df_codificado = df_codificado.compute()

# %%
df_codificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112660 entries, 0 to 112659
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     112660 non-null  int64
#  1   Unnamed: 0.1                   112660 non-null  int64
#  2   order_id                       112660 non-null  int64
#  3   order_item_id                  112660 non-null  float64
#  4   product_id                     112660 non-null  int64
#  5   seller_id                      112660 non-null  int64
#  6   shipping_limit_date            112660 non-null  int64
#  7   price                          112660 non-null  float64
#  8   freight_value                  112660 non-null  float64
#  9   payment_sequential             112660 non-null  float64
#  10  payment_type                   112660 non-null  int64
#  11  payment_installments           112660 non-null  float64
#  12  payment_value                  112660 non-null  float64
#  13  review_id                      112660 non-null  int64
#  14  review_score                   112660 non-null  float64
#  15  review_comment_title           112660 non-null  int64
#  16  review_comment_message         112660 non-null  int64
#  17  review_creation_date           112660 non-null  int64
#  18  review_answer_timestamp        112660 non-null  int64
#  19  customer_id                    112660 non-null  int64
#  20  order_status                   112660 non-null  int64
#  21  order_purchase_timestamp       112660 non-null  int64
#  22  order_approved_at              112660 non-null  int64
#  23  order_delivered_carrier_date   112660 non-null  int64
#  24  order_delivered_customer_date  112660 non-null  int64
#  25  order_estimated_delivery_date  112660 non-null  int64
#  26  customer_unique_id             112660 non-null  int64
#  27  customer_zip_code_prefix       112660 non-null  int64
#  28  customer_city                  112660 non-null  int64
#  29  customer_state                 112660 non-null  int64
#  30  seller_zip_code_prefix         112660 non-null  float64
#  31  seller_city                    112660 non-null  int64
#  32  seller_state                   112660 non-null  int64
#  33  product_category_name          112660 non-null  int64
#  34  product_name_lenght            112660 non-null  float64
#  35  product_description_lenght     112660 non-null  float64
#  36  product_photos_qty             112660 non-null  float64
#  37  product_weight_g               112660 non-null  float64
#  38  product_length_cm              112660 non-null  float64
#  39  product_height_cm              112660 non-null  float64
#  40  product_width_cm               112660 non-null  float64
#  41  costumer_lat                   112660 non-null  float64
#  42  costumer_lng                   112660 non-null  float64
#  43  seller_lat                     112660 non-null  float64
#  44  seller_lng                     112660 non-null  float64
# dtypes: float64(19), int64(26)
# memory usage: 38.7 MB

# %% [markdown]
# ##Product Category Name

# %%
fig = px.density_mapbox(df_codificado, lat='costumer_lat', lon='costumer_lng', z='product_category_name', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ##Payment Type

# %%
fig = px.density_mapbox(df_codificado, lat='costumer_lat', lon='costumer_lng', z='payment_type', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()

# %% [markdown]
# ##Order Status

# %%
fig = px.density_mapbox(df_codificado, lat='costumer_lat', lon='costumer_lng', z='order_status', radius=10,
                        center=dict(lat=0, lon=180), zoom=0, height=1000,
                        mapbox_style="stamen-terrain")
fig.show()
